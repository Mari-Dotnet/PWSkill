# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# %%
X,y=make_circles(n_samples=750,noise=0.10,factor=0.3)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.cluster import DBSCAN

# %%
cluster=DBSCAN(eps=0.10)

# %%
cluster.fit(X)
# Out:
# DBSCAN(eps=0.1)

# %%
y_pred=cluster.fit_predict(X)

# %%
cluster.labels_
# Out:
# array([ 0,  0,  0,  0,  0,  1,  8, -1,  0,  2,  3,  4,  0, -1,  5,  5,  2,
#         0,  5,  0,  0,  0,  0,  0, 10,  0,  5,  0,  0,  6,  7,  0,  0,  8,
#         0,  2,  6,  6,  1, 10,  0,  6,  0,  0,  5,  7, -1,  9,  0, 10,  5,
#         3,  9,  4,  1,  0,  6,  0,  2, 11,  0,  2,  1,  0,  0, 12,  6,  6,
#         0,  0,  0,  2,  0, 13, 12,  0,  3, 10,  0,  0,  0,  0, 14,  0, -1,
#         8,  4,  5,  0,  0,  8,  0,  8, 10,  0,  6,  0, 12,  0,  4,  0,  0,
#         0,  0,  0,  4,  7,  0, 12, 12,  6, 10,  0,  0, -1,  0,  8,  0,  0,
#         2, -1,  8,  0,  3,  4,  0,  0,  0,  0,  0,  2,  2,  0,  0, -1, 12,
#         0,  0,  4,  8,  0,  0,  0, -1,  1,  7, 13, -1,  2,  4,  1,  0,  6,
#         0, 14,  0, -1,  0,  0,  0, 10, -1,  0,  0, -1, -1,  0,  0,  5,  0,
#         3, -1,  0,  8, 10,  0,  0,  0,  0,  3,  0,  2,  0,  0,  0, -1,  0,
#        12,  0,  0,  0, 11,  0,  0,  0,  0,  0,  8,  8, 12,  0,  0, 14,  6,
#        -1,  2,  0,  0,  0, 10,  0,  0,  0, 12,  6,  0,  6, -1,  0, 13,  0,
#         0,  2,  6,  6,  0,  4,  0, -1,  0,  0,  8,  0,  2,  8, -1,  8,  1,
#         0,  0, 12,  0,  5,  0,  8,  2,  0,  2,  0, -1,  8,  4,  0,  7,  4,
#        -1,  0, 15,  3, -1,  0,  8, -1,  0,  0, 15, -1,  6, -1, -1,  0,  0,
#         0,  0,  0,  8, 10,  3,  0, 10,  7,  0,  2,  0,  0, -1,  0,  0,  0,
#         4,  3,  8,  4, 12,  0,  0,  0,  0,  0,  0,  6,  0, -1,  0,  0, -1,
#         8,  4,  2,  0,  0, 15,  6, 11,  0,  5,  0,  0,  0,  6, -1,  9,  0,
#         2,  1, -1,  0,  0, 12,  0,  0,  0, 10,  5,  2, -1,  9,  2,  0,  0,
#         0,  0,  0, 15, 12,  0, -1, -1,  0,  0,  9,  0,  0,  0,  8,  8, -1,
#        12,  4,  0, -1,  0, 10,  0,  0,  0,  8,  0,  0,  0,  0,  2,  0, 15,
#         0,  0,  0,  0,  0,  0,  8,  0, 12,  2,  0,  3,  0,  6,  0, -1,  8,
#         0,  5,  0,  0,  4,  0,  0,  2, 10,  0,  7,  9,  0,  0,  4, 14,  3,
#         0,  3, -1,  0,  0,  0,  0,  5,  0, 13, -1,  0,  6,  0,  8,  0,  0,
#         2, 10,  0,  6,  0,  0,  0,  0,  0, 13,  2,  2,  7,  6,  3,  0,  0,
#         0,  0,  4,  0,  2,  0,  0,  6,  0,  0,  1,  6, -1, 12,  0,  2, 13,
#         0,  0,  0,  6,  0,  0,  0,  0, 10,  0,  7,  3,  0,  0,  8,  0,  0,
#         0,  0,  0, 10,  1,  8,  2,  0,  0,  0,  0,  5,  0,  0,  0,  1,  0,
#         0,  0, -1,  0,  0, 10,  0,  2, -1,  8,  0,  8,  0, 11,  0,  0,  0,
#         0,  0,  2,  8,  0,  0, -1,  0, 12,  4,  2,  0,  0,  3, 10,  0,  9,
#         0,  1,  0,  6,  7,  5,  0,  0, -1,  0,  0,  0,  0,  8,  8,  0,  3,
#         4,  3,  0,  6,  0, -1,  0,  1,  2,  8,  0,  2,  0,  4,  0,  6,  0,
#         0,  0,  0, -1,  0,  0,  8,  0,  2,  0,  0,  0,  0, 10, 10,  1,  0,
#         0, -1,  3, 15,  0,  0,  0,  0,  0,  0,  5,  0, 12,  0,  4, 10,  8,
#         1,  0,  0,  6,  0,  0, 12,  0,  4,  0,  0,  2,  0,  0, -1,  0,  6,
#         0, 10,  0,  9, 12,  3,  0,  8,  2, -1,  0,  4,  7,  0,  2,  0,  0,
#        -1, 12,  8,  6,  1,  0,  9,  2, -1, -1, 10, 10,  8, -1,  0,  0,  0,
#         7,  3,  0,  2,  0,  0, -1,  4, 11,  8,  0,  0,  0,  1,  0,  0,  4,
#         2,  0,  0,  2,  0, -1,  0, 12,  2, 13,  0,  0,  0, 10,  0,  0,  0,
#         6,  0,  0,  3,  0,  8, 12,  0, 10,  0,  3,  2,  0,  8, 13,  0,  2,
#         1,  0,  2, 15,  0, -1,  0, 14,  0,  0,  0, -1,  0,  0,  0, 11,  0,
#         0,  8,  6,  0,  0,  0,  0,  0,  0,  8,  0,  5,  8,  0,  0,  9,  6,
#         0,  2,  4,  2,  1, -1,  6,  1, 10,  7,  2, 10,  0,  4,  0,  0,  0,
#         0,  0], dtype=int64)

# %%
plt.scatter(X[:,0],X[:,1],c=y_pred)

# %%
plt.scatter(X[:,0],X[:,1],c=cluster.labels_)

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
lof=LocalOutlierFactor(n_neighbors=5)

# %%
lof.fit(X)
# Out:
# LocalOutlierFactor()

# %%
y_pred = lof.fit_predict(X)

# %%
lofs_index =np.where(y_pred==-1)
values = X[lofs_index]

# %%
lof.negative_outlier_factor_

# %%
plt.scatter(X[:,0], X[:,1])
plt.scatter(values[:,0],values[:,1], color='r')
plt.show()
