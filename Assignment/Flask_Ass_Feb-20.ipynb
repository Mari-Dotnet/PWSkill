# %% [markdown]
# Q1. Explain GET and POST methods.
# - get
#   - get is used to retrive the data
#   - get don't have body of the data
#
# - post
#   - post is used to insert and update the data
#   - pass information in body of the data

# %% [markdown]
# #### Q2. Why is request used in Flask?
# - Request is used to send the data from clien to server.
# - Data recovered from get and post methods.

# %% [markdown]
# #### Q3. Why is redirect() used in Flask?
# - redirect  from one to  another target location with status code as well.

# %% [markdown]
# #### Q4. What are templates in Flask? Why is the render_template() function used?
# - templated files have static data and dynamic placeholder data.
# - render_templates its used to generate output from the tempalate view

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
# ![Postman API hit.png](attachment:12115bbd-ec0b-47a7-b047-7dc15f62ecae.png)
# ![API code screenshot.png](attachment:9f65d2bc-3f2a-44ae-be75-1561924e9062.png)
