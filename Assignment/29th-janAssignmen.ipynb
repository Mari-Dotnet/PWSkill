# %% [markdown]
# 1.who developed python program language ?
# Ans: Python was developed by Guido van Rossum.
#
# 2.which type of programing does python support?
# ans: Object oriented programmig and structure programing
#
# 3.is python case senstive dealing with identifier?
# Ans: yes, Ptthon is case sestive language
#
# 4.what is correct extension  of python file?
# Ans: .py
#
# 5.is python code compiled or interpreted?
# ans: Python code is interpreted, not compiled. An interpreted language is a type of programming language
# for which most of its implementations execute instructions directly and dynamically,
# without previously compiling a program into machine-language instructions.
#
# 6.Name a few blocks code used to define in python language?
#
# def greeting(name):
#     print("Hello, " + name)
#
# x = 10
# if x > 0:
#     print("x is positive")
#
#
# for i in range(1,11):
# 	print(i)
#
# count=0
# while count<10:
# 	count=count+1
# 	print(count)
#
#
# 7.state a charatcer used to give single line comments in python language?
#  single line comments using #
#
# 8.how to find python version?
#
# import sys
# print(sys.version)
#
# 9.Python supports the creation of anonymous function at runtime, using construct  called lambda
#
# 10.what does pip stand for python ?
#    Preferred Installer Program
#
# 11.mention few build-in function in python?
# print(), str(),int(), float(),min(),max()
#
# 12.what is maximum possible length of an identifier in python?
#   79 charatcer
#
# 13.what are the benefits of using python?
# Easy to learn: Python has a simple and intuitive syntax, making it easy for beginners to learn and get started with programming.
# Versatile: Python can be used for a wide range of tasks, including web development, scientific computing, data analysis, artificial intelligence, and more.
# Large community: Python has a large and active community of developers who contribute to its development and provide support to others.
# Plenty of libraries: Python has a rich set of libraries and tools, including NumPy, Pandas, Matplotlib, TensorFlow, and more, which makes it easy to perform complex tasks with little or no coding.
# Cross-platform compatibility: Python code can run on multiple operating systems, including Windows, macOS, and Linux, making it a great choice for developing cross-platform applications.
# Dynamically typed: Python is dynamically typed, which means that data types are determined at runtime, making it more flexible than statically typed languages.
# Easy to integrate: Python can be easily integrated with other programming languages, making it a great choice for integrating existing systems.
# Great for prototyping: Python's fast development cycle and ease of use make it a great choice for quickly prototyping ideas and experimenting with new concepts.
#
# 14. how is memory managed in python.
# memory management is handled automatically by the Python memory manager. The memory manager is responsible for allocating and freeing memory for Python objects,
# as well as handling other memory management tasks, such as garbage collection.
#
#
# 15.how to install python on windows and set path variables?
#
# Download the Python installer from the official website (https://www.python.org/downloads/windows/).
#
# Run the installer and follow the instructions to complete the installation process. Make sure to check the "Add Python to environment variables" option during the installation.
#
# Open the Command Prompt and type "python" to verify that the installation was successful. If the installation was successful, you should see the Python REPL (Read-Eval-Print Loop) prompt.
#
# To set up the path variables, open the Start menu and search for "Environment Variables".
#
# In the System Properties window, click on the "Environment Variables" button.
#
# In the Environment Variables window, scroll down to the "System Variables" section and find the "Path" variable.
#
# Click on the "Edit" button, then click on the "New" button and add the path to the Python executable file, which is usually "C:\PythonXX\python.exe", where XX is the version number of Python installed on your system.
#
# Click on "OK" to close all windows and save the changes.
#
# Restart the Command Prompt and type "python" again. This time, you should see the Python REPL prompt, which indicates that the path variables have been set up correctly.
#
# By following these steps, you can successfully install Python on Windows and set up the path variables, allowing you to run Python from the Command Prompt or any other terminal.
#
#
#
#
#
# 16.is indentation required python?
# Yes, indentation is required in Python. Indentation is used to define blocks of code, such as loops, functions, and control structures.
